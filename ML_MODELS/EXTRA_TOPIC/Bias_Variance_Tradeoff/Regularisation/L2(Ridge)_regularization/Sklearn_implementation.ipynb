# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.datasets import load_diabetes

# %%
# loading a data set
x,y = load_diabetes(return_X_y=True)
X_train, Y_train = pd.DataFrame(x), pd.DataFrame(y)

# %% [markdown]
# # rid = Ridge(alpha=1)
# rid.fit(X_train, Y_train)

# %%
print("Intercept :",rid.intercept_[0], "\nCoeff     :",rid.coef_)
# Out:
# Intercept : 152.133484162896
# Coeff     : [  29.46611189  -83.15427636  306.35268015  201.62773437    5.90961437
#   -29.51549508 -152.04028006  117.3117316   262.94429001  111.87895644]

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, root_mean_squared_error
from sklearn.model_selection import train_test_split

# %%
X_train, x_test, Y_train, y_test = train_test_split(X_train, Y_train, random_state=42, train_size=0.8)

# %%
alpha = 4
for i in range(alpha):
    ri = Ridge(alpha=i)
    ri.fit(X_train, Y_train)
    y_pred = ri.predict(x_test)
    r2 = r2_score(y_test, y_pred)
    rmse = root_mean_squared_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    print(f"{i}\nr2 score: {r2} \nRMSE    : {rmse}\nMSE     : {mse} \nMAE     :  {mae}\n\n\n")
# Out:
# 0
# r2 score: 0.4526027629719198
# RMSE    : 53.85344583676591
# MSE     : 2900.1936284934795
# MAE     :  42.79409467959994
#
#
#
# 1
# r2 score: 0.41915292635986545
# RMSE    : 55.47446204180109
# MSE     : 3077.41593882723
# MAE     :  46.13885766697452
#
#
#
# 2
# r2 score: 0.36176864948181187
# RMSE    : 58.15020675548841
# MSE     : 3381.44654570605
# MAE     :  49.05364736447028
#
#
#
# 3
# r2 score: 0.3158535117679496
# RMSE    : 60.20558041301596
# MSE     : 3624.7119128681306
# MAE     :  51.47510684708504
