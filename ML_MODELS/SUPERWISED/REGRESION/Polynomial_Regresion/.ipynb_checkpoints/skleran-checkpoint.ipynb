# %%
# This will get out put depends on a degree
"""
degree : 1 ----> intercept + degree + degree **2
these degree**2 or 3 depends on number of column
"""
# Out:
# '\ndegree : 1 ----> intercept + degree + degree **2\nthese degree**2 or 3 depends on number of column\n'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# %%
df = [
    {"x":1,"z":2,"y":7},
    {"x":2,"z":3,"y":13},
    {"x":3,"z":4,"y":21},
    {"x":4,"z":5,"y":31},
    {"x":5,"z":1,"y":28},
    {"x":6,"z":2,"y":42},
    {"x":7,"z":3,"y":58},
    {"x":8,"z":4,"y":76},
    {"x":9,"z":5,"y":96},
    {"x":10,"z":1,"y":103},
    {"x":11,"z":2,"y":127},
    {"x":12,"z":3,"y":153},
    {"x":13,"z":4,"y":181},
    {"x":14,"z":5,"y":211},
    {"x":15,"z":1,"y":228},
    {"x":16,"z":2,"y":262},
    {"x":17,"z":3,"y":298},
    {"x":18,"z":4,"y":336},
    {"x":19,"z":5,"y":376},
    {"x":20,"z":1,"y":403},
    {"x":21,"z":2,"y":447},
    {"x":22,"z":3,"y":493},
    {"x":23,"z":4,"y":541},
    {"x":24,"z":5,"y":591},
    {"x":25,"z":1,"y":628},
    {"x":26,"z":2,"y":682},
    {"x":27,"z":3,"y":738},
    {"x":28,"z":4,"y":796},
    {"x":29,"z":5,"y":856},
    {"x":30,"z":1,"y":903},
    {"x":31,"z":2,"y":967},
    {"x":32,"z":3,"y":1033},
    {"x":33,"z":4,"y":1101},
    {"x":34,"z":5,"y":1171},
    {"x":35,"z":1,"y":1228},
    {"x":36,"z":2,"y":1302},
    {"x":37,"z":3,"y":1378},
    {"x":38,"z":4,"y":1456},
    {"x":39,"z":5,"y":1536},
    {"x":40,"z":1,"y":1603},
    {"x":41,"z":2,"y":1687},
    {"x":42,"z":3,"y":1773},
    {"x":43,"z":4,"y":1861},
    {"x":44,"z":5,"y":1951},
    {"x":45,"z":1,"y":2028},
    {"x":46,"z":2,"y":2122},
    {"x":47,"z":3,"y":2218},
    {"x":48,"z":4,"y":2316},
    {"x":49,"z":5,"y":2416},
    {"x":50,"z":1,"y":2503},
    {"x":51,"z":2,"y":2607},
    {"x":52,"z":3,"y":2713},
    {"x":53,"z":4,"y":2821},
    {"x":54,"z":5,"y":2931},
    {"x":55,"z":1,"y":3028},
    {"x":56,"z":2,"y":3142},
    {"x":57,"z":3,"y":3258},
    {"x":58,"z":4,"y":3376},
    {"x":59,"z":5,"y":3496},
    {"x":60,"z":1,"y":3603}
  ]

# %%
df = pd.DataFrame(df)

# %%
df.sample()
# Out:
#      x  z     y
# 52  53  4  2821

# %%
sns.scatterplot(data = df, x = 'x', y = 'y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.scatterplot(data = df)
# Out:
# <Axes: >

# %%
X_train, x_test, Y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1])
pol = PolynomialFeatures(degree=1) # include_bias = False
pol.fit(X_train)
X_train_trans = pol.transform(X_train)
x_test_trans  = pol.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train_trans, Y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 0.        , 62.74111045,  4.64516289])

# %%
pred = lr.predict(x_test_trans)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, pred)
# Out:
# 0.9153988077365727
