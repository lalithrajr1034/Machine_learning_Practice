# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
col = df.columns[:-1]
col
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
for i in col:
    for j in col:
        sns.relplot(data = df, x=i, y=j, kind = 'scatter', hue = 'species')

# %%
pental len adn sepal len
setosa adn versicolor

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.value_counts('species')
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
data = df[['petal_length', 'sepal_length', 'species']]

# %%
dataa = data[(data['species'] =='setosa') | (data['species'] =='versicolor')]

# %%
dataa.to_csv('clasification.csv')
