# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
x,y = load_diabetes(as_frame= True, return_X_y= True)

# %%
x
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
y
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
x['target'] = y

# %%
d = x

# %%
df,test = train_test_split(d, random_state=42, train_size=0.8)

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 17   0.070769  0.050680  0.012117  0.056301  0.034206  0.049416 -0.039719
# 66  -0.009147  0.050680 -0.018062 -0.033213 -0.020832  0.012152 -0.072854
# 137  0.005383 -0.044642  0.049840  0.097615 -0.015328 -0.016345 -0.006584
# 245 -0.027310 -0.044642 -0.035307 -0.029770 -0.056607 -0.058620  0.030232
# 31  -0.023677 -0.044642 -0.065486 -0.081413 -0.038720 -0.053610  0.059685
# ..        ...       ...       ...       ...       ...       ...       ...
# 106 -0.096328 -0.044642 -0.076264 -0.043542 -0.045599 -0.034821  0.008142
# 270  0.005383  0.050680  0.030440  0.083844 -0.037344 -0.047347  0.015505
# 348  0.030811 -0.044642 -0.020218 -0.005670 -0.004321 -0.029497  0.078093
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 102 -0.092695 -0.044642  0.028284 -0.015999  0.036958  0.024991  0.056003
#
#            s4        s5        s6  target
# ...

# %%
model1 = DecisionTreeClassifier()
model2 = DecisionTreeClassifier()
model3 = DecisionTreeClassifier()
model4 = DecisionTreeClassifier()
model5 = DecisionTreeClassifier()

# %%
a = df.sample(100).index
a
# Out:
# Index([338,  81, 235, 335, 145, 127, 252, 164, 301,  63, 315, 118, 187, 345,
#        223,  80, 264,  28, 288, 110, 379,  86,   7, 251, 261, 139, 317, 267,
#        219, 243, 265, 364, 272,   5, 390, 349, 258, 322, 105, 149, 177,  26,
#        230, 437, 377,  31, 226, 257, 225, 213, 357,  38,  85,   2, 242, 389,
#        385, 414, 432, 215, 410,  49,  87, 224,  32, 355, 430, 392, 205, 233,
#        246, 350, 171, 103, 420, 180, 182, 214, 229, 259,  16, 346, 421, 408,
#        318, 173, 304,  18, 344,  74, 274, 412, 393, 210,  62, 330, 228, 279,
#        416, 166],
#       dtype='int64')

# %%
df.loc[a].iloc[:,:-1]
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 338 -0.063635 -0.044642 -0.033151 -0.033213  0.001183  0.024051 -0.024993
# 81   0.012648  0.050680 -0.022373 -0.029770  0.010815  0.028435 -0.021311
# 235  0.067136  0.050680 -0.014828  0.058608 -0.059359 -0.034508 -0.061809
# 335  0.005383 -0.044642 -0.048241 -0.012556  0.001183 -0.006637  0.063367
# 145 -0.041840 -0.044642  0.128521  0.063187 -0.033216 -0.032629  0.011824
# ..        ...       ...       ...       ...       ...       ...       ...
# 330  0.009016  0.050680  0.030440  0.042529 -0.002945  0.036890 -0.065491
# 228 -0.052738 -0.044642 -0.012673 -0.060756 -0.000193  0.008081  0.011824
# 279  0.038076  0.050680 -0.024529  0.004658 -0.026336 -0.026366  0.015505
# 416 -0.027310 -0.044642  0.080019  0.098751 -0.002945  0.018101 -0.017629
# 166 -0.056370  0.050680 -0.060097 -0.036656 -0.088254 -0.070833 -0.013948
#
#            s4        s5        s6
# 338 -0.002592 -0.022517 -0.059067
# ...

# %%
samp = 200

# %%
a1 = df.sample(samp).index
model1.fit(df.loc[a1].iloc[:,:-1], df.loc[a1].iloc[:,-1])

a2 = df.sample(samp).index
model2.fit(df.loc[a2].iloc[:,:-1], df.loc[a2].iloc[:,-1])

a3 = df.sample(samp).index
model3.fit(df.loc[a3].iloc[:,:-1], df.loc[a3].iloc[:,-1])

a4 = df.sample(samp).index
model4.fit(df.loc[a4].iloc[:,:-1], df.loc[a4].iloc[:,-1])
# Out:
# /home/lalithrajr/Machine_learning_Practice/venv/lib/python3.13/site-packages/sklearn/tree/_classes.py:297: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   check_classification_targets(y)
# /home/lalithrajr/Machine_learning_Practice/venv/lib/python3.13/site-packages/sklearn/tree/_classes.py:297: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   check_classification_targets(y)
# /home/lalithrajr/Machine_learning_Practice/venv/lib/python3.13/site-packages/sklearn/tree/_classes.py:297: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   check_classification_targets(y)
# ...

# %%
a1
# Out:
# Index([355,  37, 425, 215, 102,  41,  94,  81, 424, 375,
#        ...
#        257, 408, 236, 431, 270, 344, 401, 210, 302,  92],
#       dtype='int64', length=200)

# %%
a2
# Out:
# Index([186, 398, 265, 219, 298,  53, 246, 412, 405, 192,
#        ...
#        280, 112, 125,  17, 360, 435, 143, 432,  40, 337],
#       dtype='int64', length=200)

# %%
m1p = model1.predict(test.iloc[:,:-1])
m2p = model2.predict(test.iloc[:,:-1])
m3p = model3.predict(test.iloc[:,:-1])
m4p = model4.predict(test.iloc[:,:-1])

# %%
aa = accuracy_score
print(aa(test.iloc[:,-1], m1p))
print(aa(test.iloc[:,-1], m2p))
print(aa(test.iloc[:,-1], m3p))
print(aa(test.iloc[:,-1], m4p))
# Out:
# 0.0
# 0.011235955056179775
# 0.011235955056179775
# 0.0

# %%
X_train,X_test,y_train,y_test = train_test_split(d, random_state=42, train_size=0.8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 X_train,X_test,y_train,y_test = train_test_split(d, random_state=42, train_size=0.8)
#
# ValueError: not enough values to unpack (expected 4, got 2)
