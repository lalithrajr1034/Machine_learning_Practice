# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import BaggingRegressor, BaggingClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %%
x,y = load_breast_cancer(as_frame= True, return_X_y=True)

# %%
x
# Out:
#      mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# 0          17.99         10.38  ...          0.4601                  0.11890
# 1          20.57         17.77  ...          0.2750                  0.08902
# 2          19.69         21.25  ...          0.3613                  0.08758
# 3          11.42         20.38  ...          0.6638                  0.17300
# 4          20.29         14.34  ...          0.2364                  0.07678
# ..           ...           ...  ...             ...                      ...
# 564        21.56         22.39  ...          0.2060                  0.07115
# 565        20.13         28.25  ...          0.2572                  0.06637
# 566        16.60         28.08  ...          0.2218                  0.07820
# 567        20.60         29.33  ...          0.4087                  0.12400
# 568         7.76         24.54  ...          0.2871                  0.07039
#
# [569 rows x 30 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: target, Length: 569, dtype: int64

# %%
X_train, x_test, Y_train, y_test = train_test_split(x,y,random_state= 42, train_size=0.8)

# %%
model = DecisionTreeClassifier()

# %%
bag = BaggingClassifier(estimator=model, n_estimators= 3, max_samples= 250,n_jobs=-1,verbose=1)

# %%
bag.fit(X_train,Y_train)
# Out:
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    2.1s finished
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=250,
#                   n_estimators=3, n_jobs=-1, verbose=1)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

confusion_matrix(Y_train, bag.predict(X_train))
# Out:
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.0s finished
# array([[166,   3],
#        [  8, 278]])

# %%
accuracy_score(Y_train, bag.predict(X_train))
# Out:
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.0s finished
# 0.9758241758241758

# %% [markdown]
# <h1> Testing on test data set</h1>

# %%
confusion_matrix(y_test, bag.predict(x_test))
# Out:
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.0s finished
# array([[40,  3],
#        [ 4, 67]])

# %%
accuracy_score(y_test, bag.predict(x_test))
# Out:
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.0s finished
# 0.9385964912280702
