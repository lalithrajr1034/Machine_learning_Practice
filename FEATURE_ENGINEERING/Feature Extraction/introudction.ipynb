# %%
# here we are extraacting a new feature from a existing feature's  these are the part of a Dimensionality Reduction

# %%
# there are some methods that helps to a feature extraction 
"""
PCA
LDA
TSNE
"""
# Out:
# '\nPCA\nLDA\nTSNE\n'

# %%
# Here we are going to learn about a PCA 
# This pca is a unsuperwised learning model i completely workde in a ML_MOEDL/Unsuperwised_ml/PCA
