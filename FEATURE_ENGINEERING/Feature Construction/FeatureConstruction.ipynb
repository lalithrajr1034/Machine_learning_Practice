# %%
# In a feature constureuction we generally we extract a new feature from a existiong one

# %%
# we can understand this concept by experimenting on data,

# %%
# In theis models feature creation is very much important
"""
linear model
tree model 
dustance based models
svm  ...etc
"""
# Out:
# '\nlinear model\ntree model \ndustance based models\nsvm  ...etc\n'
