# %%
# Standardization are also called as Z-score normalization

# %%
# standardisation = (Xi - mean(X)/std(Xi))

# %%
"""When to use a standardisation """
# k-means ,KNN ,PCA, ANN(artificial neural network), Gradient Descent

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day24-standardization/Social_Network_Ads.csv"
df = pd.read_csv(url)
df.to_csv("salary.csv", index = False)

# %%
df = df[['Age', 'EstimatedSalary']]

# %%
df.head()
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            20000
# 2   26            43000
# 3   27            57000
# 4   19            76000

# %%
mean = np.mean(df['Age'])
std = np.std(df['Age'])

# %%
li = []
for i in df['Age']:
    stzation = (i-mean)/std
    li.append(stzation)

# %%
ddf1 = pd.DataFrame(li, columns=['age'])

# %%
mean = np.mean(df['EstimatedSalary'])
std  = np.std(df['EstimatedSalary'])
lis = []

# %%
for i in df['EstimatedSalary']:
    stz = (i - mean)/std
    lis.append(stz)

# %%
ddf2 = pd.DataFrame(lis, columns=["Salary"])

# %%
a = pd.concat([ddf1, ddf2] , axis = 1)

# %%
import seaborn as sns

# %%
sns.lineplot(x = "age", y = "Salary", data = a)
# Out:
# <Axes: xlabel='age', ylabel='Salary'>

# %%
sns.lineplot(x = "Age", y = "EstimatedSalary", data = df)
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.kdeplot(ddf1)
sns.kdeplot(df,)
# Out:
# <Axes: ylabel='Density'>
