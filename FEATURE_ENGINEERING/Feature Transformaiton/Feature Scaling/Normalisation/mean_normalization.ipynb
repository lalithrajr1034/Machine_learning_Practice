# %%
# Mean normalisation (we use this in a algorithm where we want a data in a center)

# %%
# Formula : 
"""  
   mean normalisation = (Xi-Xmean)/(Xmax-Xmean)\
       
"""
# here we get a +nor it a value is gt thatn mean else we get a -ve nor
# Out:
# '  \n   mean normalisation = (Xi-Xmean)/(Xmax-Xmean)       \n'

# %%
#This is used rarely used 
#this dosent have any method or a functoin in a sklearn and we manually eant to create these
