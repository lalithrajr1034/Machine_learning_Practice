# %%
#Normalisation  is a thing where data is squish in to a fixed range (0 to 1) or (-1 to 1)

# %% [markdown]
# <h3>Types of a Normalisation</h3><br>
# 1.MinMax scaling<br>
# 2.Mean normalisation<br>
# 3.Max absolute scaling<br>
# 4.Robust scaling<br> more.....
