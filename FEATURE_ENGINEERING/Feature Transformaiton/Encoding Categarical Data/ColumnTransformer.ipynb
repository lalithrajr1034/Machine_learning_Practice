# %%
# This will work on 2d shape supported things

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
# from sklearn.preprocessing import LabelEncoder  --this is 1d
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day28-column-transformer/covid_toy.csv')
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
# age - Numerical \
# geneder,city - catogarical, --Nominal
# cough   - catogarical, --ordinal

# %%
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size= 0.2)

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
ct = ColumnTransformer(transformers=[('h1', OneHotEncoder(drop = 'first', sparse_output = False), ['gender','city']),
                                     ('h2', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough'])
                                    ],remainder = 'passthrough',force_int_remainder_cols=False)

# %%
ct.fit(x_train)
# Out:
# ColumnTransformer(force_int_remainder_cols=False, remainder='passthrough',
#                   transformers=[('h1',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['gender', 'city']),
#                                 ('h2',
#                                  OrdinalEncoder(categories=[['Mild',
#                                                              'Strong']]),
#                                  ['cough'])])

# %%
ct.transform(x_train)
ct.transform(y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File L:\conda\Lib\site-packages\sklearn\base.py:420, in BaseEstimator._check_n_features(self, X, reset)
#     419 try:
# --> 420     n_features = _num_features(X)
#     421 except TypeError as e:
#
# File L:\conda\Lib\site-packages\sklearn\utils\validation.py:345, in _num_features(X)
#     344     message += f" with shape {X.shape}"
# --> 345     raise TypeError(message)
#     346 return X.shape[1]
#
# TypeError: Unable to find the number of features from X of type pandas.core.series.Series with shape (80,)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 2
#       1 ct.transform(x_train)
# ----> 2 ct.transform(y_train)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 a.head()
#
# AttributeError: 'ColumnTransformer' object has no attribute 'head'
